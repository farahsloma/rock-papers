# %%
# play with pc 
# rock vs paper => paper win
# rock vs scissor => rock win
# paper vs scissor => scissor win
# if pc and me as similer return the game

# %% [markdown]
# import random
# def choice(num,thing):
#     while True:
#         if num == 1:
#             return f"{thing} choice is Rock "
#
#         elif num == 2 :
#             return f"{thing} choice is paper "
#
#
#         elif num == 3 :
#             return f"{thing} choice is scissor "
#         else:
#             print("please enter 1 , 2 or 3 ")
#             my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : "))
#
#
#
# while True:
#     my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : "))
#     while True:
#         if num == 1:
#             return f"{thing} choice is Rock "
#
#         elif num == 2 :
#             return f"{thing} choice is paper "
#
#
#         elif num == 3 :
#             return f"{thing} choice is scissor "
#         else:
#             print("please enter 1 , 2 or 3 ")
#             my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : "))
#     pc_choice = random.choice([1, 2, 3])
#     choice(pc_choice, 'pc')
#     if (pc_choice == 1 and my_choice == 3) or (pc_choice == 2 and my_choice == 1 ) or (pc_choice == 3 and my_choice == 2) :
#         print("pc is win !!!!!")
#         break
#     elif (my_choice == 1 and pc_choice == 3) or (my_choice == 2 and pc_choice == 1 ) or (my_choice == 3 and pc_choice == 2):
#         print("you are win !!!")
#         break
#     elif my_choice == pc_choice :
#         print("the pc is choice the same choice you choice it \nplease try again ")

# %%
import random
while True : 
    my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : ")) 
    while True:  
        if my_choice == 1:
            print( f"your choice is Rock ")
            break

        elif my_choice == 2 :
            print( f"your choice is paper ")
            break

        elif my_choice == 3 :
            print( f"your choice is scissor ")
            break
        else:
            print("please enter 1 , 2 or 3 ")
            my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : "))
    pc_choice = random.choice([1, 2, 3])
    if  pc_choice == 1:
            print( f"pc choice is Rock ")
    elif pc_choice == 2 :
        print( f"pc choice is paper ")
    elif pc_choice == 3 :
        print( f"pc choice is scissor ")


    if (pc_choice == 1 and my_choice == 3) or (pc_choice == 2 and my_choice == 1 ) or (pc_choice == 3 and my_choice == 2) :
        print("pc is win !!!!!")
    elif (my_choice == 1 and pc_choice == 3) or (my_choice == 2 and pc_choice == 1 ) or (my_choice == 3 and pc_choice == 2):
        print("you are win !!!")

    elif my_choice == pc_choice :
        print("the pc is choice the same choice you choice it \nplease try again ")
    answer = int(input('do you would play again ?\t1-yes\t 2- no '))
    while True: 
        if answer == 1:
            print('you will play again nice !!!')
            break
        elif answer == 2 :
            print("good bay")
            break
        else:
            print("please enter 1 or 2")
            answer = int(input('do you would play again ?\t1-yes\t 2- no '))
    if answer==2:
        break
# Out:
# please enter your choice number
# 1-Rock	2-paper 	3- scissor : 3
# your choice is scissor
# pc choice is Rock
# pc is win !!!!!
# do you would play again ?	1-yes	 2- no 1
# you will play again nice !!!
# please enter your choice number
# 1-Rock	2-paper 	3- scissor : 6
# please enter 1 , 2 or 3
# please enter your choice number
# 1-Rock	2-paper 	3- scissor : 2
# your choice is paper
# pc choice is scissor
# pc is win !!!!!
# do you would play again ?	1-yes	 2- no 2
# good bay

# %%
import random
while True : 
    my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : ")) 
    while True:  
        if my_choice == 1:
            print( f"your choice is Rock ")
            break

        elif my_choice == 2 :
            print( f"your choice is paper ")
            break

        elif my_choice == 3 :
            print( f"your choice is scissor ")
            break
        else:
            print("please enter 1 , 2 or 3 ")
            my_choice = int(input("please enter your choice number \n1-Rock\t2-paper \t3- scissor : "))
    pc_choice = random.choice([1, 2, 3])
    if  pc_choice == 1:
            print( f"pc choice is Rock ")
    elif pc_choice == 2 :
        print( f"pc choice is paper ")
    elif pc_choice == 3 :
        print( f"pc choice is scissor ")


    if (pc_choice == 1 and my_choice == 3) or (pc_choice == 2 and my_choice == 1 ) or (pc_choice == 3 and my_choice == 2) :
        print("pc is win !!!!!")
    elif (my_choice == 1 and pc_choice == 3) or (my_choice == 2 and pc_choice == 1 ) or (my_choice == 3 and pc_choice == 2):
        print("you are win !!!")

    elif my_choice == pc_choice :
        print("the pc is choice the same choice you choice it \nplease try again ")
    answer = int(input('do you would play again ?\t1-yes\t 2- no '))
    while True: 
        if answer == 1:
            print('you will play again nice !!!')
            break
        elif answer == 2 :
            print("good bay")
            break
        else:
            print("please enter 1 or 2")
            answer = int(input('do you would play again ?\t1-yes\t 2- no '))
    if answer==2:
        break
# Out:
# please enter your choice number
# 1-Rock	2-paper 	3- scissor : 3
# your choice is scissor
# pc choice is paper
# you are win !!!
# do you would play again ?	1-yes	 2- no 2
# good bay
